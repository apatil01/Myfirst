# %%
#import ssl
#if hasattr(ssl, '_create_unverified_context'):
#    ssl._create_default_https_context = ssl._create_unverified_context

#import the library used to query a website

import requests
from bs4 import BeautifulSoup

#specify the url
url = "https://homeroom5.doe.state.nj.us/directory/charter.php"

#Query the website and return the html to the variable 'page'
#page = urllib.urlopen(wiki)
r = requests.get(url, verify=False)

#import the Beautiful soup functions to parse the data returned from the website


#Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(r.content)

school_name = soup.find_all("h3")
#print soup.prettify()
#for name in school_name:
#    print name.text

right_div=soup.find_all('div', class_='district_box')

for row in right_div:
    mailing_address = row.findAll("p")
#for m_address in mailing_address:
    print mailing_address[1].text
# Out:
# C:\Users\apatil\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\packages\urllib3\connectionpool.py:821: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# Mailing Address
#   112 South New York Rd.
#
#   Galloway, NJ 08205
#
# Grade Levels: 09 10 11 12
# Grade Levels: KG 01 02 03
# Mailing Address
#   200 MCARTHUR AVENUE
#
#   GARFIELD, NJ 07026
#
# Grade Levels: KG 01 02 03 04 05 06
# Grade Levels: KG 01 02 03 04 05 06 07 08
# Mailing Address
#   PO Box 128
#
#   Willingboro, NJ 08046
#
# Grade Levels: KG 01 02 03
# Grade Levels: KG 01 02 03 04 05 06 07 08
# Grade Levels: KG 01 02 03 04 05 06 07 08 09 10 11 12
# Grade Levels: KG 01 02 03 04 05
# Grade Levels: KG 01 02 03 04 05 06 07 08 09 10 11
# Grade Levels: KG 01 02 03 04
# Grade Levels: KG 01 02 03 04 05 06 07 08 09 10 11 12
# Grade Levels: KG 01 02 03 04 05 06
# Grade Levels: KG
# Mailing Address
#   342 Central Avenue
#
#   Newark, NJ 07103
#
# Grade Levels: KG 01 02
# Grade Levels: KG 01 02 03 04 05
# Grade Levels: KG 01 02 03 04 05 06 07
# Mailing Address
#   2560 Industrial Way
# , Suite C
#   VINELAND, NJ 08360
#
# Grade Levels: KG 01 02 03 04 05
# Grade Levels: 04 05 06 07 08
# Grade Levels: KG 01 02 03 04
# Grade Levels: PK KG 01 02 03 04 05 06 07 08 09 10 11 12
# Grade Levels: KG 01 02 03 04 05 06 07 08
# Grade Levels: 05 06 07 08
# Mailing Address
#   233 Woodside Avenue
#
#   NEWARK, NJ 07104
#
# Grade Levels: PK KG 01 02 03 04 05 06 07 08 09 10 11 12
# Grade Levels: 06 07 08 09
# Grade Levels: KG 01 02 03 04 05 06
# Grade Levels: PK KG 01 02 03 04
# Grade Levels: 09 10 11 12
# Grade Levels: KG 01 02 03 04 05 06 07 08 09 10 11 12
# Grade Levels: 09 10 11 12
# Grade Levels: 09 10 11 12
