# %%
#import ssl
#if hasattr(ssl, '_create_unverified_context'):
#    ssl._create_default_https_context = ssl._create_unverified_context

#import the library used to query a website

import requests
from bs4 import BeautifulSoup

#specify the url
url = "https://homeroom5.doe.state.nj.us/directory/charter.php"

#Query the website and return the html to the variable 'page'
#page = urllib.urlopen(wiki)
r = requests.get(url, verify=False)

#import the Beautiful soup functions to parse the data returned from the website


#Parse the html in the 'page' variable, and store it in Beautiful Soup format
soup = BeautifulSoup(r.content)
A =[]
B =[]
C =[]
D =[]

school_name = soup.find_all("h3")
#print soup.prettify()
for name in school_name:
    clean_name = name.text
    A.append(clean_name)
#    print name.text
del A[0]

right_div = soup.find_all('div', class_='district_box')

#for row in right_div:
#    mailing_address = row.findAll("p")
#    for m_address in mailing_address:
#        new_only_address = m_address[1]
#        only_address = m_address.findAll("p")
#    clean_mailing_address = mailing_address[1].text
#     B.append(mailing_address[1])
#        print only_address



for contact in right_div:
    cont = contact.findAll("table")
    clean_cont = cont[0].text 
    C.append(clean_cont)
#    print cont[0].text
   
 
#print len(A)
#print (B)
print len(C)

import pandas as pd
df = pd.DataFrame(columns=[A, C])
df

#df.to_csv('example.csv')
# Out:
# C:\Users\apatil\AppData\Local\Continuum\Anaconda2\lib\site-packages\requests\packages\urllib3\connectionpool.py:821: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# 88
# Empty DataFrame
# Columns: [(Atlantic Community Charter School (6060),
# Ms Jessica  Richard, School Lead
# (609)541-3149
# jrichard@atlanticcitycharter.com
# Ms Jane  Migliori-bilik, Director of Special Education
# (609)541-3149
# Ms Jessica  Richard, Anti-Bullying Coordinator
# (609)541-3149
# Ms Penni  Starer, Anti-Bullying Specialist
# (856)541-3149
# ), (Chartertech High School for the Performing Arts (7410),
# Dr Brian  McGuire, School Lead
# (609)926-7694
# bmcguire@chartertech.org
# Mrs Adrienne  Breitinger, Director of Special Education
# (609)926-7694
# Ms Lisa  Borchardt, Anti-Bullying Coordinator
# (609)926-7694
# ...

# %%
df1 = pd.DataFrame([A, C])
df2 = df1.T

df2.to_csv('example2.csv')

# %%
df1.iloc[1].apply(lambda x: x.split('\n') )
# Out:
# 0     [, Ms Jessica  Richard, School Lead, (609)541-...
# 1     [, Dr Brian  McGuire, School Lead, (609)926-76...
# 2     [, Mrs Natakie  Chestnut, Chief School Adminis...
# 3     [, Mr Nihat  Guvercin, School Lead, (201)773-9...
# 4     [, Dr Shirl  Burns, Principal, (201)569-9765, ...
# 5     [, Mr Ralph  Gallo, School Lead, (201)833-9600...
# 6     [, Mr Richard  Wilson Jr, School Lead, (609)53...
# 7     [, Ms Beth  Kelley, Chief School Administrator...
# 8     [, Ms Andrea  Surratt, Principal, (856)635-031...
# 9     [, Dr Joseph  Conway, School Lead, (856)365-10...
# 10    [, Dr Antoinette  Dendtler, Chief School Admin...
# 11    [, Mr Ronald  Brady, School Director, (856)962...
# 12    [, Mrs Robin  Ruiz, School Lead, (856)379-3448...
# 13    [, Mr Manuel  Delgado, School Lead, (856)614-3...
# 14    [, Mrs Wandria  McCall-Hampton, School Adminis...
# 15    [, Ms MONICA  VILLAFUERTE, Chief School Admini...
# 16    [, Ms Regina  Lauricella, School Principal, (9...
# ...
